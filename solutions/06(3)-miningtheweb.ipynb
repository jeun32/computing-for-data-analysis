# %% [markdown]
# # Part 2: Mining the web: Web APIs<a href="#Part-2:-Mining-the-web:-Web-APIs" class="anchor-link">¶</a>
#
# We hope the preceding exercise was painful: even with tools to process
# HTML, it is rough downloading raw HTML and trying to extract information
# from it!
#
# > Can you think of any other reasons why scraping websites for data in
# > this way is not a good idea?
#
# Luckily, many websites provide an application programming interface
# (API) for querying their data or otherwise accessing their services from
# your programs. For instance, Twitter provides a web API for gathering
# tweets, Flickr provides one for gathering image data, and Github for
# accessing information about repository histories.
#
# These kinds of web APIs are much easier to use than, for instance, the
# preceding technique which scrapes raw web pages and then has to parse
# the resulting HTML. Moreover, there are more scalable in the sense that
# the web servers can transmit structured data in a less verbose form than
# raw HTML.
#
# As a starting example, here is some code to look at the activity on
# Github related to the public version of our course's materials.
#
# In \[1\]:
#
#     import requests
#
#     response = requests.get ('https://api.github.com/repos/cse6040/labs-fa17/events')
#
#     print ("==> .headers:", response.headers, "\n")
#
#     ==> .headers: {'Date': 'Thu, 13 Sep 2018 15:00:47 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Server': 'GitHub.com', 'Status': '200 OK', 'X-RateLimit-Limit': '60', 'X-RateLimit-Remaining': '39', 'X-RateLimit-Reset': '1536854091', 'Cache-Control': 'public, max-age=60, s-maxage=60', 'Vary': 'Accept, Accept-Encoding', 'ETag': 'W/"5c97aec56241b5a106f606e7122db3f2"', 'Last-Modified': 'Sat, 25 Aug 2018 13:32:20 GMT', 'X-Poll-Interval': '60', 'X-GitHub-Media-Type': 'github.v3; format=json', 'Access-Control-Expose-Headers': 'ETag, Link, Retry-After, X-GitHub-OTP, X-RateLimit-Limit, X-RateLimit-Remaining, X-RateLimit-Reset, X-OAuth-Scopes, X-Accepted-OAuth-Scopes, X-Poll-Interval', 'Access-Control-Allow-Origin': '*', 'Strict-Transport-Security': 'max-age=31536000; includeSubdomains; preload', 'X-Frame-Options': 'deny', 'X-Content-Type-Options': 'nosniff', 'X-XSS-Protection': '1; mode=block', 'Referrer-Policy': 'origin-when-cross-origin, strict-origin-when-cross-origin', 'Content-Security-Policy': "default-src 'none'", 'X-Runtime-rack': '0.072938', 'Content-Encoding': 'gzip', 'X-GitHub-Request-Id': 'CFA6:43F4:17189AE:1E46A51:5B9A7B9F'}
#
# Note the `Content-Type` of the response:
#
# In \[2\]:
#
#     print (response.headers['Content-Type'])
#
#     application/json; charset=utf-8
#
# The response is in JSON format, which is an open format for exchanging
# semi-structured data. (JSON stands for **J**ava**S**cript **O**bject
# **N**otation.) JSON is designed to be human-readable and
# machine-readable, and maps especially well in Python to nested
# dictionaries. Let's take a look.
#
# > See also [this
# > tutorial](https://www.w3schools.com/js/js_json_intro.asp) for a JSON
# > primer. JSON is among *the* universal formats for sharing data on the
# > web; see, for instance,
# > <https://www.sitepoint.com/10-example-json-files/>.
#
# In \[3\]:
#
#     import json
#     print(type(response.json ()))
#     print(json.dumps(response.json()[:3], sort_keys=True, indent=2))
#
#     <class 'list'>
#     [
#       {
#         "actor": {
#           "avatar_url": "https://avatars.githubusercontent.com/u/37394743?",
#           "display_login": "chanafee",
#           "gravatar_id": "",
#           "id": 37394743,
#           "login": "chanafee",
#           "url": "https://api.github.com/users/chanafee"
#         },
#         "created_at": "2018-08-25T13:32:20Z",
#         "id": "8166752267",
#         "org": {
#           "avatar_url": "https://avatars.githubusercontent.com/u/31073927?",
#           "gravatar_id": "",
#           "id": 31073927,
#           "login": "cse6040",
#           "url": "https://api.github.com/orgs/cse6040"
#         },
#         "payload": {
#           "forkee": {
#             "archive_url": "https://api.github.com/repos/chanafee/labs-fa17/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/chanafee/labs-fa17/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/chanafee/labs-fa17/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/chanafee/labs-fa17/branches{/branch}",
#             "clone_url": "https://github.com/chanafee/labs-fa17.git",
#             "collaborators_url": "https://api.github.com/repos/chanafee/labs-fa17/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/chanafee/labs-fa17/comments{/number}",
#             "commits_url": "https://api.github.com/repos/chanafee/labs-fa17/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/chanafee/labs-fa17/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/chanafee/labs-fa17/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/chanafee/labs-fa17/contributors",
#             "created_at": "2018-08-25T13:32:20Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/chanafee/labs-fa17/deployments",
#             "description": "Lab notebooks for the Fall 2017 offering of Georgia Tech's CSE 6040",
#             "downloads_url": "https://api.github.com/repos/chanafee/labs-fa17/downloads",
#             "events_url": "https://api.github.com/repos/chanafee/labs-fa17/events",
#             "fork": true,
#             "forks": 0,
#             "forks_count": 0,
#             "forks_url": "https://api.github.com/repos/chanafee/labs-fa17/forks",
#             "full_name": "chanafee/labs-fa17",
#             "git_commits_url": "https://api.github.com/repos/chanafee/labs-fa17/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/chanafee/labs-fa17/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/chanafee/labs-fa17/git/tags{/sha}",
#             "git_url": "git://github.com/chanafee/labs-fa17.git",
#             "has_downloads": true,
#             "has_issues": false,
#             "has_pages": false,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": null,
#             "hooks_url": "https://api.github.com/repos/chanafee/labs-fa17/hooks",
#             "html_url": "https://github.com/chanafee/labs-fa17",
#             "id": 146097862,
#             "issue_comment_url": "https://api.github.com/repos/chanafee/labs-fa17/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/chanafee/labs-fa17/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/chanafee/labs-fa17/issues{/number}",
#             "keys_url": "https://api.github.com/repos/chanafee/labs-fa17/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/chanafee/labs-fa17/labels{/name}",
#             "language": null,
#             "languages_url": "https://api.github.com/repos/chanafee/labs-fa17/languages",
#             "license": null,
#             "merges_url": "https://api.github.com/repos/chanafee/labs-fa17/merges",
#             "milestones_url": "https://api.github.com/repos/chanafee/labs-fa17/milestones{/number}",
#             "mirror_url": null,
#             "name": "labs-fa17",
#             "node_id": "MDEwOlJlcG9zaXRvcnkxNDYwOTc4NjI=",
#             "notifications_url": "https://api.github.com/repos/chanafee/labs-fa17/notifications{?since,all,participating}",
#             "open_issues": 0,
#             "open_issues_count": 0,
#             "owner": {
#               "avatar_url": "https://avatars1.githubusercontent.com/u/37394743?v=4",
#               "events_url": "https://api.github.com/users/chanafee/events{/privacy}",
#               "followers_url": "https://api.github.com/users/chanafee/followers",
#               "following_url": "https://api.github.com/users/chanafee/following{/other_user}",
#               "gists_url": "https://api.github.com/users/chanafee/gists{/gist_id}",
#               "gravatar_id": "",
#               "html_url": "https://github.com/chanafee",
#               "id": 37394743,
#               "login": "chanafee",
#               "node_id": "MDQ6VXNlcjM3Mzk0NzQz",
#               "organizations_url": "https://api.github.com/users/chanafee/orgs",
#               "received_events_url": "https://api.github.com/users/chanafee/received_events",
#               "repos_url": "https://api.github.com/users/chanafee/repos",
#               "site_admin": false,
#               "starred_url": "https://api.github.com/users/chanafee/starred{/owner}{/repo}",
#               "subscriptions_url": "https://api.github.com/users/chanafee/subscriptions",
#               "type": "User",
#               "url": "https://api.github.com/users/chanafee"
#             },
#             "private": false,
#             "public": true,
#             "pulls_url": "https://api.github.com/repos/chanafee/labs-fa17/pulls{/number}",
#             "pushed_at": "2017-11-26T05:20:15Z",
#             "releases_url": "https://api.github.com/repos/chanafee/labs-fa17/releases{/id}",
#             "size": 34810,
#             "ssh_url": "git@github.com:chanafee/labs-fa17.git",
#             "stargazers_count": 0,
#             "stargazers_url": "https://api.github.com/repos/chanafee/labs-fa17/stargazers",
#             "statuses_url": "https://api.github.com/repos/chanafee/labs-fa17/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/chanafee/labs-fa17/subscribers",
#             "subscription_url": "https://api.github.com/repos/chanafee/labs-fa17/subscription",
#             "svn_url": "https://github.com/chanafee/labs-fa17",
#             "tags_url": "https://api.github.com/repos/chanafee/labs-fa17/tags",
#             "teams_url": "https://api.github.com/repos/chanafee/labs-fa17/teams",
#             "trees_url": "https://api.github.com/repos/chanafee/labs-fa17/git/trees{/sha}",
#             "updated_at": "2018-08-15T05:22:49Z",
#             "url": "https://api.github.com/repos/chanafee/labs-fa17",
#             "watchers": 0,
#             "watchers_count": 0
#           }
#         },
#         "public": true,
#         "repo": {
#           "id": 100506580,
#           "name": "cse6040/labs-fa17",
#           "url": "https://api.github.com/repos/cse6040/labs-fa17"
#         },
#         "type": "ForkEvent"
#       },
#       {
#         "actor": {
#           "avatar_url": "https://avatars.githubusercontent.com/u/42422510?",
#           "display_login": "chenkang001",
#           "gravatar_id": "",
#           "id": 42422510,
#           "login": "chenkang001",
#           "url": "https://api.github.com/users/chenkang001"
#         },
#         "created_at": "2018-08-15T22:21:19Z",
#         "id": "8119691403",
#         "org": {
#           "avatar_url": "https://avatars.githubusercontent.com/u/31073927?",
#           "gravatar_id": "",
#           "id": 31073927,
#           "login": "cse6040",
#           "url": "https://api.github.com/orgs/cse6040"
#         },
#         "payload": {
#           "forkee": {
#             "archive_url": "https://api.github.com/repos/chenkang001/labs-fa17/{archive_format}{/ref}",
#             "archived": false,
#             "assignees_url": "https://api.github.com/repos/chenkang001/labs-fa17/assignees{/user}",
#             "blobs_url": "https://api.github.com/repos/chenkang001/labs-fa17/git/blobs{/sha}",
#             "branches_url": "https://api.github.com/repos/chenkang001/labs-fa17/branches{/branch}",
#             "clone_url": "https://github.com/chenkang001/labs-fa17.git",
#             "collaborators_url": "https://api.github.com/repos/chenkang001/labs-fa17/collaborators{/collaborator}",
#             "comments_url": "https://api.github.com/repos/chenkang001/labs-fa17/comments{/number}",
#             "commits_url": "https://api.github.com/repos/chenkang001/labs-fa17/commits{/sha}",
#             "compare_url": "https://api.github.com/repos/chenkang001/labs-fa17/compare/{base}...{head}",
#             "contents_url": "https://api.github.com/repos/chenkang001/labs-fa17/contents/{+path}",
#             "contributors_url": "https://api.github.com/repos/chenkang001/labs-fa17/contributors",
#             "created_at": "2018-08-15T22:21:19Z",
#             "default_branch": "master",
#             "deployments_url": "https://api.github.com/repos/chenkang001/labs-fa17/deployments",
#             "description": "Lab notebooks for the Fall 2017 offering of Georgia Tech's CSE 6040",
#             "downloads_url": "https://api.github.com/repos/chenkang001/labs-fa17/downloads",
#             "events_url": "https://api.github.com/repos/chenkang001/labs-fa17/events",
#             "fork": true,
#             "forks": 0,
#             "forks_count": 0,
#             "forks_url": "https://api.github.com/repos/chenkang001/labs-fa17/forks",
#             "full_name": "chenkang001/labs-fa17",
#             "git_commits_url": "https://api.github.com/repos/chenkang001/labs-fa17/git/commits{/sha}",
#             "git_refs_url": "https://api.github.com/repos/chenkang001/labs-fa17/git/refs{/sha}",
#             "git_tags_url": "https://api.github.com/repos/chenkang001/labs-fa17/git/tags{/sha}",
#             "git_url": "git://github.com/chenkang001/labs-fa17.git",
#             "has_downloads": true,
#             "has_issues": false,
#             "has_pages": false,
#             "has_projects": true,
#             "has_wiki": true,
#             "homepage": null,
#             "hooks_url": "https://api.github.com/repos/chenkang001/labs-fa17/hooks",
#             "html_url": "https://github.com/chenkang001/labs-fa17",
#             "id": 144909090,
#             "issue_comment_url": "https://api.github.com/repos/chenkang001/labs-fa17/issues/comments{/number}",
#             "issue_events_url": "https://api.github.com/repos/chenkang001/labs-fa17/issues/events{/number}",
#             "issues_url": "https://api.github.com/repos/chenkang001/labs-fa17/issues{/number}",
#             "keys_url": "https://api.github.com/repos/chenkang001/labs-fa17/keys{/key_id}",
#             "labels_url": "https://api.github.com/repos/chenkang001/labs-fa17/labels{/name}",
#             "language": null,
#             "languages_url": "https://api.github.com/repos/chenkang001/labs-fa17/languages",
#             "license": null,
#             "merges_url": "https://api.github.com/repos/chenkang001/labs-fa17/merges",
#             "milestones_url": "https://api.github.com/repos/chenkang001/labs-fa17/milestones{/number}",
#             "mirror_url": null,
#             "name": "labs-fa17",
#             "node_id": "MDEwOlJlcG9zaXRvcnkxNDQ5MDkwOTA=",
#             "notifications_url": "https://api.github.com/repos/chenkang001/labs-fa17/notifications{?since,all,participating}",
#             "open_issues": 0,
#             "open_issues_count": 0,
#             "owner": {
#               "avatar_url": "https://avatars1.githubusercontent.com/u/42422510?v=4",
#               "events_url": "https://api.github.com/users/chenkang001/events{/privacy}",
#               "followers_url": "https://api.github.com/users/chenkang001/followers",
#               "following_url": "https://api.github.com/users/chenkang001/following{/other_user}",
#               "gists_url": "https://api.github.com/users/chenkang001/gists{/gist_id}",
#               "gravatar_id": "",
#               "html_url": "https://github.com/chenkang001",
#               "id": 42422510,
#               "login": "chenkang001",
#               "node_id": "MDQ6VXNlcjQyNDIyNTEw",
#               "organizations_url": "https://api.github.com/users/chenkang001/orgs",
#               "received_events_url": "https://api.github.com/users/chenkang001/received_events",
#               "repos_url": "https://api.github.com/users/chenkang001/repos",
#               "site_admin": false,
#               "starred_url": "https://api.github.com/users/chenkang001/starred{/owner}{/repo}",
#               "subscriptions_url": "https://api.github.com/users/chenkang001/subscriptions",
#               "type": "User",
#               "url": "https://api.github.com/users/chenkang001"
#             },
#             "private": false,
#             "public": true,
#             "pulls_url": "https://api.github.com/repos/chenkang001/labs-fa17/pulls{/number}",
#             "pushed_at": "2017-11-26T05:20:15Z",
#             "releases_url": "https://api.github.com/repos/chenkang001/labs-fa17/releases{/id}",
#             "size": 34810,
#             "ssh_url": "git@github.com:chenkang001/labs-fa17.git",
#             "stargazers_count": 0,
#             "stargazers_url": "https://api.github.com/repos/chenkang001/labs-fa17/stargazers",
#             "statuses_url": "https://api.github.com/repos/chenkang001/labs-fa17/statuses/{sha}",
#             "subscribers_url": "https://api.github.com/repos/chenkang001/labs-fa17/subscribers",
#             "subscription_url": "https://api.github.com/repos/chenkang001/labs-fa17/subscription",
#             "svn_url": "https://github.com/chenkang001/labs-fa17",
#             "tags_url": "https://api.github.com/repos/chenkang001/labs-fa17/tags",
#             "teams_url": "https://api.github.com/repos/chenkang001/labs-fa17/teams",
#             "trees_url": "https://api.github.com/repos/chenkang001/labs-fa17/git/trees{/sha}",
#             "updated_at": "2018-08-15T05:22:49Z",
#             "url": "https://api.github.com/repos/chenkang001/labs-fa17",
#             "watchers": 0,
#             "watchers_count": 0
#           }
#         },
#         "public": true,
#         "repo": {
#           "id": 100506580,
#           "name": "cse6040/labs-fa17",
#           "url": "https://api.github.com/repos/cse6040/labs-fa17"
#         },
#         "type": "ForkEvent"
#       },
#       {
#         "actor": {
#           "avatar_url": "https://avatars.githubusercontent.com/u/36866962?",
#           "display_login": "cookblaze",
#           "gravatar_id": "",
#           "id": 36866962,
#           "login": "cookblaze",
#           "url": "https://api.github.com/users/cookblaze"
#         },
#         "created_at": "2018-08-15T05:22:49Z",
#         "id": "8115173219",
#         "org": {
#           "avatar_url": "https://avatars.githubusercontent.com/u/31073927?",
#           "gravatar_id": "",
#           "id": 31073927,
#           "login": "cse6040",
#           "url": "https://api.github.com/orgs/cse6040"
#         },
#         "payload": {
#           "action": "started"
#         },
#         "public": true,
#         "repo": {
#           "id": 100506580,
#           "name": "cse6040/labs-fa17",
#           "url": "https://api.github.com/repos/cse6040/labs-fa17"
#         },
#         "type": "WatchEvent"
#       }
#     ]
#
# **Exercise 0.** It should be self-evident that the JSON response above
# consists of a sequence of records, which we will refer to as *events*.
# Each event is associated with an *actor*. Write some code to extract a
# dictionary of all actors, where the key is the actor's login and the
# value is the actor's URL.
#
# In \[4\]:
#
#     def extract_actors (json_github_events):
#         """Given JSON records for events in a GitHub repo,
#         returns a dictionary of the actors and their URLs.
#         """
#         ### BEGIN SOLUTION
#         urls = {}
#         for event in json_github_events:
#             actor = event['actor']['display_login']
#             url = event['actor']['url']
#             urls[actor] = url
#         return urls
#         ### END SOLUTION
#
# In \[5\]:
#
#     actor_urls = extract_actors(response.json ())
#
#     for actor, url in actor_urls.items ():
#         print ('{}: {}'.format(actor, url))
#         assert url == "https://api.github.com/users/{}".format(actor)
#
#     chanafee: https://api.github.com/users/chanafee
#     chenkang001: https://api.github.com/users/chenkang001
#     cookblaze: https://api.github.com/users/cookblaze
#     dwrussell: https://api.github.com/users/dwrussell
#     fractalbass: https://api.github.com/users/fractalbass
#     msa444: https://api.github.com/users/msa444
#     tonyelhabr: https://api.github.com/users/tonyelhabr
#     zili-chen: https://api.github.com/users/zili-chen
#     bryanlie: https://api.github.com/users/bryanlie
#
# **Exercise 1.** Write some code that goes to each actor's URL and
# determines their name. If an actor URL is invalid, that actor should not
# appear in the output.
#
# In \[6\]:
#
#     def lookup_names (actor_urls):
#         """Given a dictionary of (actor, url) pairs, looks up the JSON at
#         the URL and extracts the user's name (if any). Returns a new
#         dictionary of (actor, name) pairs.
#         """
#         ### BEGIN SOLUTION
#         import re
#
#         names = {}
#         for actor, url in actor_urls.items ():
#             response = requests.get (url)
#
#             # Possible error conditions
#             if response is None: continue
#             if re.search ('application/json', response.headers['Content-Type']) is None: continue
#             if 'name' not in response.json (): continue
#
#             names[actor] = response.json ()['name']
#         return names
#         ### END SOLUTION
#
# In \[7\]:
#
#     actor_names = lookup_names (actor_urls)
#
#     for actor, name in actor_names.items ():
#         print ("{}: {}".format (actor, name))
#
#     assert actor_names['bryanlie'] == 'Dan Li'
#
#     chanafee: None
#     chenkang001: None
#     cookblaze: None
#     dwrussell: None
#     fractalbass: Miles Porter
#     msa444: None
#     tonyelhabr: Tony ElHabr
#     zili-chen: Zili Chen
#     bryanlie: Dan Li
#
# That's the end of this notebook. Processing JSON is fairly
# straightforward, because it maps very naturally to nested dictionaries
# in Python. You might search the web for other sources of JSON data,
# including [this one](https://www.yelp.com/dataset/challenge), and do
# your own processing!
